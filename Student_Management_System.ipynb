# %%
class Student:
    def __init__(self, id, name, email):
        self.__id = id
        self.__name = name
        self.__email = email
        self.__course = []

    def get_id(self):
        return self.__id

    def get_name(self):
        return self.__name

    def get_email(self):
        return self.__email

    def get_courses(self):
        return self.__course

    def set_name(self, name):
        self.__name = name

    def set_email(self, email):
        self.__email = email

    def add_course(self, course):
        self.__course.append(course)

    def view_details(self):
        print("ID:", self.__id)
        print("Name:", self.__name)
        print("Email:", self.__email)
        if self.__course:
            print("Enrolled Courses:")
            for c in self.__course:
                print(f"{c.id} | {c.course_name} | Credits: {c.credits}")
        else:
            print("No courses enrolled")

    def display_students(self):
        print("ID:", self.__id)
        print("Name:", self.__name)
        print("Email:", self.__email)


class Course:
    def __init__(self, id, course_name, credits):
        self.id = id
        self.course_name = course_name
        self.credits = credits

    def display_courses(self):
        print("Course ID:", self.id)
        print("Course Name:", self.course_name)
        print("Credits:", self.credits)


class Remove_student:
    def remove_student(self, students, student_id):
        for student in students:
            if student.get_id() == student_id:
                students.remove(student)
                print(f"Student with ID {student_id} removed successfully!")
                return
        print(f"Student with ID {student_id} not found.")


class Remove_course:
    def remove_course(self, courses, course_id):
        for course in courses:
            if course.id == course_id:
                courses.remove(course)
                print(f"Course with ID {course_id} removed successfully!")
                return
        print(f"Course with ID {course_id} not found.")


students = []
courses = []

while True:
    print("\n--- Student Management System ---")
    print("1. Add Student")
    print("2. Add Course")
    print("3. Enroll Student")
    print("4. View Students")
    print("5. View Details")
    print("6. Remove Student")
    print("7. Remove Course")
    print("8. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        student_id = input("Enter Student ID: ")
        student_name = input("Enter Student Name: ")
        student_email = input("Enter Student Email: ")
        new_student = Student(student_id, student_name, student_email)
        students.append(new_student)
        print(f"Student {student_name} added successfully!")

    elif choice == "2":
        course_id = input("Enter Course ID: ")
        course_name = input("Enter Course Name: ")
        course_credits = input("Enter course credits: ")
        new_course = Course(course_id, course_name, course_credits)
        courses.append(new_course)
        print(f"Course {course_name} added successfully!")

    elif choice == "3":
        student_id = input("Enter Student ID: ")
        course_id = input("Enter Course ID: ")

        student_found = None
        for student in students:
            if student.get_id() == student_id:
                student_found = student
                break

        course_found = None
        for course in courses:
            if course.id == course_id:
                course_found = course
                break

        if student_found and course_found:
            student_found.add_course(course_found)
            print(f"Student {student_id} enrolled in course {course_id}")
        else:
            print("Student or course not found")

    elif choice == "4":
        if students:
            print("\n--- Student List ---")
            for student in students:
                student.display_students()
                print()
        else:
            print("No students to display")

    elif choice == "5":
        student_id = input("Enter Student ID: ")
        student_found = None
        for student in students:
            if student.get_id() == student_id:
                student_found = student
                break

        if student_found:
            print("\n--- Student Details ---")
            student_found.view_details()
        else:
            print("Student not found")

    elif choice == "6":
        student_id = input("Enter Student ID to remove: ")
        remover = Remove_student()
        remover.remove_student(students, student_id)

    elif choice == "7":
        course_id = input("Enter Course ID to remove: ")
        remover = Remove_course()
        remover.remove_course(courses, course_id)

    elif choice == "8":
        print("Exiting the program.")
        break

    else:
        print("Invalid choice. Please try again.")
# Out:
# --- Student Management System ---
# 1. Add Student
# 2. Add Course
# 3. Enroll Student
# 4. View Students
# 5. View Details
# 6. Remove Student
# 7. Remove Course
# 8. Exit
# Enter your choice: 1
# Enter Student ID: 22013115
# Enter Student Name: Atik Sahukhala
# Enter Student Email: atik.sahukhala@gmail.com
# Student Atik Sahukhala added successfully!
#
# --- Student Management System ---
# 1. Add Student
# 2. Add Course
# 3. Enroll Student
# 4. View Students
# 5. View Details
# 6. Remove Student
# 7. Remove Course
# 8. Exit
# Enter your choice: 2
# Enter Course ID: 321
# Enter Course Name: BCS
# Enter course credits: 5
# Course BCS added successfully!
#
# --- Student Management System ---
# 1. Add Student
# 2. Add Course
# 3. Enroll Student
# 4. View Students
# 5. View Details
# 6. Remove Student
# 7. Remove Course
# 8. Exit
# Enter your choice: 3
# Enter Student ID: 220013115
# Enter Course ID: 321
# Student or course not found
#
# --- Student Management System ---
# 1. Add Student
# 2. Add Course
# 3. Enroll Student
# 4. View Students
# 5. View Details
# 6. Remove Student
# 7. Remove Course
# 8. Exit
# Enter your choice: 3
# Enter Student ID: 22013115
# Enter Course ID: 321
# Student 22013115 enrolled in course 321
#
# --- Student Management System ---
# 1. Add Student
# 2. Add Course
# 3. Enroll Student
# 4. View Students
# 5. View Details
# 6. Remove Student
# 7. Remove Course
# 8. Exit
# Enter your choice: 4
#
# --- Student List ---
# ID: 22013115
# Name: Atik Sahukhala
# Email: atik.sahukhala@gmail.com
#
#
# --- Student Management System ---
# 1. Add Student
# 2. Add Course
# 3. Enroll Student
# 4. View Students
# 5. View Details
# 6. Remove Student
# 7. Remove Course
# 8. Exit
# Enter your choice: 5
# Enter Student ID: 22013115
#
# --- Student Details ---
# ID: 22013115
# Name: Atik Sahukhala
# Email: atik.sahukhala@gmail.com
# Enrolled Courses:
# 321 | BCS | Credits: 5
#
# --- Student Management System ---
# 1. Add Student
# 2. Add Course
# 3. Enroll Student
# 4. View Students
# 5. View Details
# 6. Remove Student
# 7. Remove Course
# 8. Exit
# Enter your choice: 6
# Enter Student ID to remove: 22013115
# Student with ID 22013115 removed successfully!
#
# --- Student Management System ---
# 1. Add Student
# 2. Add Course
# 3. Enroll Student
# 4. View Students
# 5. View Details
# 6. Remove Student
# 7. Remove Course
# 8. Exit
# Enter your choice: 7
# Enter Course ID to remove: 321
# Course with ID 321 removed successfully!
#
# --- Student Management System ---
# 1. Add Student
# 2. Add Course
# 3. Enroll Student
# 4. View Students
# 5. View Details
# 6. Remove Student
# 7. Remove Course
# 8. Exit
# Enter your choice: 8
# Exiting the program.
